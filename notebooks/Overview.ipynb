# %%
import os
print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# C:\Users\vinay kumar\OneDrive\Documents\vinay\ML_Project\ai-workplace-productivity-analysis

# %%
print(os.listdir())
# Out:
# ['classification', 'clustering', 'data', 'final_model', 'notebooks', 'preprocessing', 'README.md', 'requirements.txt', 'ui', 'venv', 'visualizations']

# %%
import os

os.chdir(r"C:\Users\vinay kumar\OneDrive\Documents\vinay\ML_Project\ai-workplace-productivity-analysis")

print(os.getcwd())
print(os.listdir("data"))
# Out:
# C:\Users\vinay kumar\OneDrive\Documents\vinay\ML_Project\ai-workplace-productivity-analysis
# ['train.csv']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/train.csv")
df.head()
# Out:
#   Employee_Id  Avg_Working_Hours_Per_Day Work_From  Work_Pressure  \
# 0     EMP0001                        6.7      Home              3
# 1     EMP0002                        6.9      Home              1
# 2     EMP0003                       15.1    Office              3
# 3     EMP0004                       10.7    Hybrid              3
# 4     EMP0005                       11.8      Home              2
#
#    Manager_Support  Sleeping_Habit  Exercise_Habit  Job_Satisfaction  \
# 0                4               4               2                 5
# 1                1               5               4                 3
# 2                2               3               5                 1
# 3                2               5               3                 2
# 4                2               4               1                 5
#
#   Work_Life_Balance  Social_Person Lives_With_Family Working_State  \
# 0                No              5               Yes     Karnataka
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_Id                3000 non-null   str
#  1   Avg_Working_Hours_Per_Day  3000 non-null   float64
#  2   Work_From                  3000 non-null   str
#  3   Work_Pressure              3000 non-null   int64
#  4   Manager_Support            3000 non-null   int64
#  5   Sleeping_Habit             3000 non-null   int64
#  6   Exercise_Habit             3000 non-null   int64
#  7   Job_Satisfaction           3000 non-null   int64
#  8   Work_Life_Balance          3000 non-null   str
#  9   Social_Person              3000 non-null   int64
#  10  Lives_With_Family          3000 non-null   str
#  11  Working_State              3000 non-null   str
#  12  Stress_Level               3000 non-null   int64
# dtypes: float64(1), int64(7), str(5)
# memory usage: 375.7 KB

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 3000
# Columns: 13

# %%
df.isnull().sum()
# Out:
# Employee_Id                  0
# Avg_Working_Hours_Per_Day    0
# Work_From                    0
# Work_Pressure                0
# Manager_Support              0
# Sleeping_Habit               0
# Exercise_Habit               0
# Job_Satisfaction             0
# Work_Life_Balance            0
# Social_Person                0
# Lives_With_Family            0
# Working_State                0
# Stress_Level                 0
# dtype: int64

# %%
df.describe()
# Out:
#        Avg_Working_Hours_Per_Day  Work_Pressure  Manager_Support  \
# count                3000.000000    3000.000000      3000.000000
# mean                    9.303300       3.017000         2.992000
# std                     1.864299       1.401439         1.408284
# min                     4.300000       1.000000         1.000000
# 25%                     8.100000       2.000000         2.000000
# 50%                     9.100000       3.000000         3.000000
# 75%                    10.300000       4.000000         4.000000
# max                    16.000000       5.000000         5.000000
#
#        Sleeping_Habit  Exercise_Habit  Job_Satisfaction  Social_Person  \
# count     3000.000000     3000.000000       3000.000000    3000.000000
# mean         3.030000        2.985000          2.984000       2.992333
# std          1.381691        1.402889          1.419536       1.402948
# min          1.000000        1.000000          1.000000       1.000000
# ...

# %%
sns.countplot(x="Stress_Level", data=df)
plt.title("Stress Level Distribution")
plt.show()

# %%
sns.boxplot(x="Stress_Level", y="Avg_Working_Hours_Per_Day", data=df)
plt.title("Working Hours vs Stress Level")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
sns.countplot(x="Social_Person", hue="Stress_Level", data=df)
plt.title("Social Personality vs Stress Level")
plt.show()
